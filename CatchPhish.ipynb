# %% [markdown]
# <a href="https://colab.research.google.com/github/KubraErensoy/Phising/blob/main/CatchPhish.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_excel("Catch_phish-1.xlsx")

# %%
data.columns
# Out:
# Index(['http://007indien.blogspot.com/2013/08/daftar-link-kementerian-dan-lembaga.html', 0], dtype='object')

# %%
data.rename(columns={'http://007indien.blogspot.com/2013/08/daftar-link-kementerian-dan-lembaga.html'    :'SiteName',
                     0  :'PhishDetail',
                     },inplace=True)
data.head()
# Out:
#                                             SiteName  PhishDetail
# 0                          http://021jiaju.com/xhsd/          0.0
# 1     http://03.rospotrebnadzor.ru/content/336/9833/          0.0
# 2           http://039.holidayblog.jp/?cat=7&paged=2          0.0
# 3  http://03online.com/news/boli_vnizu_zhivota_za...          0.0
# 4  http://03online.com/news/dissotsiatsiya_1_tipa...          0.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 126062 entries, 0 to 126061
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SiteName     126062 non-null  object
#  1   PhishDetail  122056 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 1.9+ MB

# %%
data.shape
# Out:
# (126062, 2)

# %%
data.isnull().sum(axis=0)
# Out:
# SiteName          0
# PhishDetail    4006
# dtype: int64

# %%
data = data.dropna()

# %%
data.isnull().sum(axis=0)
# Out:
# SiteName       0
# PhishDetail    0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 122056 entries, 0 to 126061
# Data columns (total 2 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   SiteName     122056 non-null  object
#  1   PhishDetail  122056 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 2.8+ MB

# %%
#uyarıları kapatıyoruz
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
#PROTOCOL
import re
import openpyxl
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 protocol,sep,tail=str(cell_obj.value).partition('://')
 print(protocol)
 #o = urlparse (cell_obj.value)
 #print(o)
#verimiz büyük olduğu için çıkış değerlerinin bir kısmını  kırparak aşağıda verilmiştir.

# %% [markdown]
# ![protocol.png](data:image/png;base64,...)

# %%
#PROTOCOLSUZ SITE
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 domain=re.sub(r'(www+\.)',"",str(x))
 print(domain)

# %% [markdown]
# ![protocolsuzsite.png](data:image/png;base64,...)

# %%
#PROTOCOLSUZ SITE LENGTH
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 domain=re.sub(r'(www+\.)',"",str(x))
 print (len(domain))

# %% [markdown]
# ![protocolsuzsitelength.png](data:image/png;base64,...)

# %%
#DOMAIN
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 #print(x)
 head,sep,tail=str(x).partition('/')
 #xy=re.sub(r'\/+',"", str(x))
 #print(head)
 domain=re.sub(r'(www+\.)',"",str(head))
 print(domain)
 #o = urlparse (cell_obj.value)
 #print(o.netloc)

# %% [markdown]
# ![domain.png](data:image/png;base64,...)

# %%
#DOMAINLENGTH
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 #print(x)
 head,sep,tail=str(x).partition('/')
 #xy=re.sub(r'\/+',"", str(x))
 #print(head)
 domain=re.sub(r'(www+\.)',"",str(head))
 #print(domain)
 print (len(domain))

# %% [markdown]
# ![domainlength.png](data:image/png;base64,...)

# %%
#BLOGSPOTLU
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 #print(x)
 head,sep,tail=str(x).partition('/')
 #xy=re.sub(r'\/+',"", str(x))
 #print(head)
 domain=re.sub(r'(www+\.)',"",str(head))
 #print(domain)
 level=re.sub(r'(\.[^.]*$)',"",str(domain))
 print(level)

# %% [markdown]
# ![blogspot.png](data:image/png;base64,...)

# %%
#SECOND LEVEL DOMAIN
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 #print(x)
 head,sep,tail=str(x).partition('/')
 #xy=re.sub(r'\/+',"", str(x))
 #print(head)
 domain=re.sub(r'(www+\.)',"",str(head))
 #print(domain)
 level=re.sub(r'\..*',"",str(domain))
 #level=re.sub(r'(\.[^.]*)',"",str(domain))
 #bu da oldu
 #d,y,z=str(domain).partition('.') print(d)
 print(level)

# %% [markdown]
# ![2leveldomain.png](data:image/png;base64,...)

# %%
#SECOND LEVEL DOMAIN LENGTH
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 #print(x)
 head,sep,tail=str(x).partition('/')
 #xy=re.sub(r'\/+',"", str(x))
 #print(head)
 domain=re.sub(r'(www+\.)',"",str(head))
 #print(domain)
 level=re.sub(r'\..*',"",str(domain))
 print (len(level))

# %% [markdown]
# ![2leveldomainlength.png](data:image/png;base64,...)

# %%
#TOP LEVEL DOMAIN
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 #print(x)
 head,sep,tail=str(x).partition('/')
 #xy=re.sub(r'\/+',"", str(x))
 #print(head)
 domain=re.sub(r'(www+\.)',"",str(head))
 #print(domain)
 level=re.sub(r'.*\.',"",str(domain))
 print(level)

# %% [markdown]
# ![topleveldomain.png](data:image/png;base64,...)

# %%
import re
import openpyxl

# %%
#directory
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 domain=re.sub(r'(www+\.)',"",str(x))
 result = re.search('\/(.*)\/', domain)
 if result == None:
    print ("None")
 else:
    print(result.group(1))
 #if result is not None:
 # if result.group(1):
 # print(result)

# %% [markdown]
# ![directory.png](data:image/png;base64,...)

# %%
#directory length
path = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(path) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 domain=re.sub(r'(www+\.)',"",str(x))
 result = re.search('\/(.*)\/', domain)
 if result == None:
    print ("0")
 else:
    print (len(result.group(1)))
 #if result is not None:
 # if result.group(1):
 # print(result)

# %% [markdown]
# ![directorylength.png](data:image/png;base64,...)

# %%
#htmlsiz file page
import os
from urllib.parse import urlparse
from os import path
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
      cell_obj = sheet_obj.cell(row = i, column = 1)
      x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
      domain=re.sub(r'(www+\.)',"",str(x))
      substring="/"
      if re.search(substring, domain):
          firstpos=domain.rfind("/")
          lastpos=domain.rfind(".") #?
          aa=(domain[firstpos+1:lastpos])
          if aa is '':
            print ("None")
          else:
            ttt=re.sub(r'(\?.*)',"",str(aa)) #?
            ccc=re.sub(r'(\.([^.]*)$)',"",str(ttt))
            print(ccc)
      else:
          print ("None")

# %% [markdown]
# ![htmlsizfilepage.png](data:image/png;base64,...)

# %%
#htmlsiz file page length
import os
from urllib.parse import urlparse
from os import path
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
    cell_obj = sheet_obj.cell(row = i, column = 1)
    x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
    domain=re.sub(r'(www+\.)',"",str(x))
    substring="/"
    if re.search(substring, domain):
      firstpos=domain.rfind("/")
      lastpos=domain.rfind(".") #?
      aa=(domain[firstpos+1:lastpos])
      if aa is '':
        print ("None")
      else:
        ttt=re.sub(r'(\?.*)',"",str(aa)) #?
        ccc=re.sub(r'(\.([^.]*)$)',"",str(ttt))
        print (len(ccc))
    else:
     print ("None")

# %% [markdown]
# ![htmlsizfilepagelength.png](data:image/png;base64,...)

# %%
#url parse
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh)
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 print(o)
 
 #domain name
 # print(o.netloc)

# %% [markdown]
# ![Urlparse.png](data:image/png;base64,...)

# %%
#Path
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 if o.path is '':
  print ("/")
 else: 
  print(o.path)

# %% [markdown]
# ![path.png](data:image/png;base64,...)

# %%
#Path length
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 if o.path is '':
  print ("1")
 else: 
  print (len(o.path))

# %% [markdown]
# ![pathlength.png](data:image/png;base64,...)

# %%
#Query
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 if o.query is '':
  print ("None")
 else:
  print(o.query)

# %% [markdown]
# ![query.png](data:image/png;base64,...)

# %%
#Query length
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 if o.query is '':
  print ("0")
 else:
  print (len(o.query))

# %% [markdown]
# ![querylength.png](data:image/png;base64,...)

# %%
#fragment length
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 if o.fragment is '':
   print ("0")
 else:
   print (len(o.fragment))

# %% [markdown]
# ![fragmentlength.png](data:image/png;base64,...)

# %%
#fragment
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 if o.fragment is '':
  print ("None")
 else:
  print(o.fragment)

# %% [markdown]
# ![fragment.png](data:image/png;base64,...)

# %%
#reserved characters
#https://skorks.com/2010/05/what-every-developer-should-know-about-urls/
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 counter = o.path.count(';') + o.path.count('/') + o.path.count('?') + o.path.count(':') + o.path.count('@') + o.path.count('&') + o.path.count('=') + o.path.count('+') + o.path.count('$') + o.path.count(',')
 print (str(counter))

# %% [markdown]
# ![reversedcharecters.png](data:image/png;base64,...)

# %%
#num of delimiters?
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 counter = o.path.count('<') + o.path.count('>') + o.path.count('#') + o.path.count('%') + o.path.count('"')
 print (str(counter))

# %% [markdown]
# ![numofdelimeters.png](data:image/png;base64,...)

# %%
#unreserved characters
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 counter = o.path.count('-') + o.path.count('_') + o.path.count('.') + o.path.count('!') + o.path.count('~') + o.path.count('*') + o.path.count("'") + o.path.count('(') + o.path.count(')')
 print (str(counter))

# %% [markdown]
# ![unreversedcharacters.png](data:image/png;base64,...)

# %%
#unwise characters
#https://skorks.com/2010/05/what-every-developer-should-know-about-urls/
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 counter = o.path.count('{') + o.path.count('}') + o.path.count('|') + o.path.count("\\") + o.path.count('^') + o.path.count('[') + o.path.count("]") + o.path.count('`')
 print (str(counter))

# %% [markdown]
# ![unwisecharacters.png](data:image/png;base64,...)

# %%
#Belirli bir URL için Query String içinde anahtar-değer çiftlerinin elde edilmesi 
#görevi için urlparse modülü bize parseqs metodunu sağlıyor.
#https://medium.com/@sddkal/python-urlparse-mod%C3%BCl%C3%BC-e77771eb391b
from urllib.parse import urlparse
from urllib.parse import parse_qs
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 print (parse_qs(o.query))

# %% [markdown]
# ![urlparse2.png](data:image/png;base64,...)

# %%
#https://medium.com/@sddkal/python-urlparse-mod%C3%BCl%C3%BC-e77771eb391b
from urllib.parse import urlparse
from urllib.parse import parse_qs
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 print (o.port)
 # sum falan yapmaya ve daire şeklinde göstermeye bak.

# %% [markdown]
# ![urlparse3.png](data:image/png;base64,...)

# %%
#url parse domain name
from urllib.parse import urlparse
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 o = urlparse (cell_obj.value)
 print(o.netloc)

# %% [markdown]
# ![urlparsedomainname.png](data:image/png;base64,...)

# %%
#Oldu galiba
import os
from urllib.parse import urlparse
from os import path
pathh = "Catch_phish-1.xlsx"
wb_obj = openpyxl.load_workbook(pathh) 
sheet_obj = wb_obj.active 
m_row = sheet_obj.max_row 
# Loop will print all values 
# of first column 
for i in range(1, m_row + 1):
 cell_obj = sheet_obj.cell(row = i, column = 1)
 x=re.sub(r'(https+\://|http+\://)',"", str(cell_obj.value))
 domain=re.sub(r'(www+\.)',"",str(x))
 substring="/"
 if re.search(substring, domain):
  print(os.path.basename(domain)) # Output: 09-09-201315-47-571378756077.jpg
 else:
  print ("None")

# %% [markdown]
# ![son.png](data:image/png;base64,...)
